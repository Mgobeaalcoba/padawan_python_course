# %% [markdown]
# ## 1. Graficos de barras
# Se utiliza para comparar valores discretos o categóricos entre diferentes grupos.

# %%
# @title Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# @title Create DataFrame step
df = pd.read_csv("https://raw.githubusercontent.com/Statology/Python-Guides/main/default.csv")

# %%
# @title Inspection step
df.sample(5)
# Out:
#       default  student      balance        income
# 3618        0        0   542.842025  48897.752544
# 355         0        0   717.341927  44266.376540
# 7694        0        1   819.912191  16585.028099
# 5451        0        0   741.844666  45808.540281
# 8194        1        0  1562.837918  49303.009468

# %%
# @title Set auxiliaries variables
x = 'income'
y = 'balance'
category = 'student'
category2 = 'default'

# %%
# @title Barplot con suma

## Seteo el grafico de barras de suma con apertura de segmento
sns.barplot(data=df,
            x=category,
            y=y,
            estimator='sum')

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel('Sum '+ y)
plt.title('Grafico de barra')

## Muestro el gráfico resultante
plt.show()

# %% [markdown]
# #### La suma de balance no ve con claridad porque está escrito de forma exponencial dado que es un número muy grande. Podemos recurrir entonces a transformar/agregar nuestro "balance" a/en miles (K) y volver a graficar con el

# %%
df["balance_K"] = df["balance"] / 1000
df.sample(5)
# Out:
#       default  student      balance        income  balance_K
# 4781        0        0  1147.978075  40515.690457   1.147978
# 5388        0        0  1468.788055  38521.870200   1.468788
# 6680        0        0   639.625675  38660.923225   0.639626
# 987         0        0   240.841553  56089.154251   0.240842
# 9804        0        0  1508.749012  30587.343982   1.508749

# %%
# @title Repito mi Barplot en miles

## Seteo el grafico de barras de suma
sns.barplot(data=df,
            x=category,
            y=df["balance_K"], # Cambio mi eje Y por la nueva columna creada
            estimator='sum')

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel('Sum balance K')
plt.title('Grafico de barra')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Barplot con promedio

## Grafico de barras de promedio
sns.barplot(data=df,
            x=category,
            y=y,
            estimator='mean')

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel('Average '+y)
plt.title('Grafico de barra')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Barplot de promedio aperturado por segmento

## Grafico de barras de promedio con apertura de segmento
sns.barplot(data=df,
            x=category,
            y=y,
            hue=category2,
            estimator='mean')

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel('Average '+y)
plt.title('Grafico de barra')

## Muestro el gráfico resultante
plt.show()

# %% [markdown]
# ## 2. Graficos de Lineas
# Se utiliza para mostrar cambios en una variable a lo largo del tiempo o en función de otra variable.

# %%
# @title Create DataFrame step
df2 = pd.read_csv('https://www.dropbox.com/s/4jgheggd1dak5pw/data_visualization.csv?raw=1', index_col=0)
df2['args'] = np.random.choice([0, 1],size=len(df2.index)) # Creamos una columna nueva con números enteros entre 0 y 1 escogidos aleatoriamente.

# %%
# @title Inspection step
df2.head()
# Out:
#          arrow     under      interior         theta         amb  \
# 0  5718.086525 -1.614321  1.555158e+11  11213.081938   95.426020
# 1  3230.167947  0.066989  1.853956e+12  21130.628512   12.420615
# 2  7557.771756 -0.067705  8.501664e+10  13804.152665  152.939420
# 3  6555.190363 -1.253076  1.194396e+12   7549.844014  457.351838
# 4  3201.371780  0.327282  5.787566e+11  32745.773149  228.577117
#
#           slice       delta            pi        height            nu  \
# 0   7425.427256  -10.406357   9680.358706  7.120126e+06  1.546267e+07
# 1  12649.208494 -115.874083   8052.298378  2.075786e+07  4.522003e+06
# 2   9134.779756  -30.421137   1246.712864  1.078952e+07  6.069516e+06
# 3   2475.142419 -129.555563   5177.525187  7.995510e+05  2.238686e+07
# 4   1545.254659 -101.958575  14579.206899  3.122909e+05  5.824294e+07
#
#        night       dataset    length          twi          x          wind  \
# ...

# %%
# @title Set auxiliaries variables for regression
x = 'height'
y = 'slice'
category = 'args'

# %%
# @title Ordeno mi dataframe de forma ascendente(por default) por mi columna 'height
df2 = df2.sort_values(x)
df2.head()
# Out:
#             arrow     under      interior         theta         amb     slice  \
# 30    4559.608362  1.098399  7.443036e+09  12329.922768  258.962159   0.00000
# 271   7236.861830  0.345462  5.934236e+11    759.451765  419.404844  13.67482
# 208   3793.695917 -0.418125  6.429946e+11  43824.834188   67.460352  41.02446
# 191   5488.592094 -1.832353  4.974720e+10   7996.580346  381.849149  27.34964
# 362  10379.640658  1.232179  3.508269e+11  37257.810104  193.737060  82.04892
#
#          delta            pi       height            nu      night  \
# 30  -16.094788  13552.502188   122.917996  1.593056e+07  10.454982
# 271 -46.857295   5837.549644   297.093100  2.025225e+07  15.062162
# 208 -66.798298  13845.846391   348.447227  4.619419e+07   9.747587
# 191 -32.837454  11469.758345   417.085404  2.203178e+07   9.429322
# 362 -37.594923    469.350725  1065.169378  4.586739e+07   7.283030
#
#           dataset    length          twi          x          wind          y  \
# ...

# %%
# @title Lineplot

## Grafico de linea para poder identificar distribución
sns.lineplot(data=df2,
             x=x,
             y=y,
             linestyle='--',
             linewidth=2)

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Gráfico de lineas')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Lineplot aperturado por "args"

## Grafico de linea agregando categoria
sns.lineplot(data=df2,
             x=x,
             y=y,
             linestyle='--',
             linewidth=2,
             hue=category)

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Gráfico de lineas')

## Muestro el gráfico resultante
plt.show()

# %% [markdown]
# ## Grafico de Dispersion
# Se utiliza para mostrar la relación entre dos variables numéricas

# %%
# @title Create DataFrame step
df3 = pd.read_csv("https://raw.githubusercontent.com/Statology/Python-Guides/main/default.csv")
df3.tail(3)
# Out:
#       default  student      balance        income
# 9997        0        0   845.411989  58636.156984
# 9998        0        0  1569.009053  36669.112365
# 9999        0        1   200.922183  16862.952321

# %%
# @title Set auxiliaries variables
y = 'income'
x = 'balance'
category = 'student'
categroy2= 'default'

# %%
# @title Lmplot

## Grafico de dispersion
sns.lmplot(data=df3,
           x=x,
           y=y,
           scatter_kws={"s": 1})

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Grafico de dispersion')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Lmplot open by category

## Grafico de dispersion aperturada por categoria
sns.lmplot(data=df3,
           x=x,
           y=y,
           hue=category,
           scatter_kws={"s": 1})

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Grafico de dispersion')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Lmplot of two columns

## Grafico de dispersion aperturado por categoria según el color (hue) y por columna según segunda categoria (col)
sns.lmplot(data=df3, x=x, y=y, hue=category, col=categroy2, scatter_kws={"s": 10})

## Seteo los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)

## Muestro el gráfico resultante
plt.show()

# %% [markdown]
# ## Grafico de Histograma
# Se utiliza para mostrar la distribución de una variable numérica.

# %%
# @title Create DataFrame step
df4 = pd.read_csv("https://raw.githubusercontent.com/Statology/Python-Guides/main/default.csv")
df4.sample(6)
# Out:
#       default  student      balance        income
# 6681        0        0  1051.847749  37160.273303
# 5348        0        1  1407.497272  14688.388904
# 805         0        1   450.305391  21177.611078
# 4781        0        0  1147.978075  40515.690457
# 5406        0        1  1292.568784  14859.240085
# 7124        0        1  1279.316806  17837.034551

# %%
# @title Set auxiliaries variables
y = 'income'
x = 'balance'
category = 'student'

# %%
# @title Histplot

## Histograma por cantidad de bins
sns.histplot(data=df4,
             x=x,
             bins=20,
             color='purple')

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Histograma')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Histplot open by category

## Agrego apertura por categoria
sns.histplot(data=df, x=x, bins=20, hue=category)

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Histograma')

## Muestro el gráfico resultante
plt.show()

# %%
# @title Histplot with trends lines

## Agrego lineas de tendencia
sns.histplot(data=df, x=x, bins=20, hue=category, kde=True, multiple='dodge', stat='percent')

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Histograma')

## Muestro el gráfico resultante
plt.show()

# %% [markdown]
# ## Grafico de Boxplot
# Se utiliza para mostrar la distribución de una variable numérica y destacar los valores atípicos.

# %%
# @title Create DataFrame step
df5 = pd.read_csv("https://raw.githubusercontent.com/Statology/Python-Guides/main/default.csv")
df5.head(7)
# Out:
#    default  student      balance        income
# 0        0        0   729.526495  44361.625074
# 1        0        1   817.180407  12106.134700
# 2        0        0  1073.549164  31767.138947
# 3        0        0   529.250605  35704.493935
# 4        0        0   785.655883  38463.495879
# 5        0        1   919.588530   7491.558572
# 6        0        0   825.513331  24905.226578

# %%
# @title Set auxiliaries variables
y = 'income'
x = 'balance'
category = 'student'

# %%
# @title Boxplot open by category

## Construyo mi boxplot
sns.boxplot(data=df5,
            x=category,
            y=y)

## Seteo el titulo y los nombres de los ejes
plt.xlabel(x)
plt.ylabel(y)
plt.title('Boxplot')

## Muestro el gráfico resultante
plt.show()

# %% [markdown]
# ## Challenges:
#
# 1. Agarra el "df5" y hacé un boxplot de "balance"
# 2. Usa Numpy para crear un array de numeros enteros aleatorios entre 0 y 1 y crear una nueva columna en el df5 que se llame: "challenge_tag". Pista: En la sección 2 "Gráficos de lineas" podrás encontrar una ayuda para resolverlo-
# 3. Hacé el mismo boxplot del punto 1 pero ahora aperturalo por la nueva columna creada.
# 4. Arma un histograma, un gráfico de barras y un gráfico de lineas a eleccion con el dataframe que más te haya gustado.
